# %%
using Astrodynamics
using DerIMDEX
using ODE
using jspice
using PyPlot
# Out:
# Loading help data...

# %%
mu=planets["earth"]["mu"]
RE=planets["earth"]["re"]
# Out:
# 6378.1363

# %%
hp=185
inc=28.5*pi/180
e=0.975000919
node=86.83224*pi/180
argp=-129.98616*pi/180
jd0=2458119.33552
dt=5.23359
# Out:
# 5.23359

# %%
rp=hp+RE
# Out:
# 6563.1363

# %%
a=rp/(1-e)
# Out:
# 262535.1027903782

# %%
el=[a;e;inc;node;argp;0]
# Out:
# 6-element Array{Float64,1}:
#  262535.0
#       0.975001
#       0.497419
#       1.51551
#      -2.26869
#       0.0

# %%
x0=cartesian(el,planets["earth"]["mu"])
# Out:
# 6-element Array{Float64,1}:
#   4179.47
#  -4455.25
#  -2399.48
#      6.63923
#      8.03688
#     -3.35817

# %%
gregorian(jd0,"jd")
# Out:
# (2017,12,31,20,3,8.928017020225525)

# %%
et0=(jd0-julian(2000,1,1,0,0,0,"jd")-0.5)*86400
# Out:
# 5.68022588928017e8

# %%
et1=et0+dt*86400
# Out:
# 5.68474771104017e8

# %%
jsinit()

# %%
@time traj=ode45(der,[et0;et1],x0);
# Out:
# elapsed time: 0.
# 05810237 seconds (10131744 bytes allocated)

# %%
typeof(traj)
# Out:
# (Array{Float64,1},Array{Float64,2})

# %%
traj[2][1,1:6]
# Out:
# 1x6 Array{Float64,2}:
#  4179.47  -4455.25  -2399.48  6.63923  8.03688  -3.35817

# %%
x=traj[2][:,1];
y=traj[2][:,2];
z=traj[2][:,3];

# %%
frlin=plot3D(x,y,z);
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x10a6cdf10>)
